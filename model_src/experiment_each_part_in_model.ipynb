# %% [markdown]
# To see the difference before cropping the image

# %%
from P_model_9_CH import crop_with_points, transform
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

filepath = r"D:\clone_audio\chinese_audio_dataset_ver3\test_mel_spec\bonafide_melspec_SSB01330093.png"
img = Image.open(filepath)
cropped_image = crop_with_points(filepath).convert('RGB')
transformed_image = transform(crop_with_points(filepath).convert('RGB'))
reshaped_image = np.transpose(transformed_image, (1, 2, 0))
# Display the image before cropped
print("Before Cropped:")
plt.imshow(img, cmap='gray')
# plt.axis('off')
plt.show()
print(np.array(img).shape)

# Display the cropped image
print("After Cropped:")
plt.imshow(cropped_image, cmap='gray')
# plt.axis('off')
plt.show()

print(np.array(cropped_image).shape)

# Display the transformed image
print("After Transformed:")
plt.imshow(reshaped_image, cmap='gray')
# plt.axis('off')
plt.show()

print(np.array(reshaped_image).shape)
# Out:
# Before Cropped:
# (480, 640, 4)
# After Cropped:
# (371, 496, 3)
# After Transformed:
# (128, 128, 3)

# %% [markdown]
# My method:
# 1. Turn into an image by using `matplotlib`, then save this image.
# 2. Then, read it and resize it into (128, 128).

# %%
from P_model_9_CH import crop_with_points, transform
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

filepath = r"D:\graduate_project\feature_extraction_src\melspec_output_9.png"
img = Image.open(filepath)
cropped_image = crop_with_points(filepath).convert('RGB')
transformed_image = transform(crop_with_points(filepath).convert('RGB'))
reshaped_image = np.transpose(transformed_image, (1, 2, 0))
# Display the image before cropped
print("Before Cropped:")
plt.imshow(img, cmap='gray')
# plt.axis('off')
plt.show()
print(np.array(img).shape)

# Display the cropped image
print("After Cropped:")
plt.imshow(cropped_image, cmap='gray')
# plt.axis('off')
plt.show()

print(np.array(cropped_image).shape)
# print(np.array(cropped_image))
# Display the transformed image
print("After Transformed:")
plt.imshow(reshaped_image, cmap='gray')
# plt.axis('off')
plt.show()
# print(reshaped_image)
print(np.array(reshaped_image).shape)
# Out:
# Before Cropped:
# (480, 640, 4)
# After Cropped:
# (371, 496, 3)
# After Transformed:
# (128, 128, 3)

# %% [markdown]
# The other method:
# 1. Turn into an image by using `opencv`, then save this image in dimension (128, 128).
# 2. Then, read it.

# %% [markdown]
# To see the image came from opencv, the image seem to be upside down.
# * original shape is already (128 , 128)
# * I compare my way and this opencv way. I think this two method is almost the same result. It seems all OK.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

filepath = r"D:\graduate_project\feature_extraction_src\mel_spectrogram.jpg"
img = Image.open(filepath)


# Display the image before cropped
print("See the image came from opencv method:")
plt.imshow(img, cmap='gray')
# plt.axis('off')
plt.show()
print(np.array(img).shape)
# Out:
# See the image came from opencv method:
# (128, 128)
